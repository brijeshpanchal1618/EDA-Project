# %% [markdown]
# <a href="https://colab.research.google.com/github/brijeshpanchal1618/EDA-Project/blob/main/Model_Testing_for_housedata.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv('Cleaned_kc_house_data.csv')
df.head()
# Out:
#    Unnamed: 0             date     price  bedrooms  bathrooms  sqft_living  \
# 0           0  20141013T000000  221900.0         3       1.00         1180
# 1           1  20141209T000000  538000.0         3       2.25         2570
# 2           2  20150225T000000  180000.0         2       1.00          770
# 3           3  20141209T000000  604000.0         4       3.00         1960
# 4           4  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams["figure.figsize"] = (10,8)

# %%
plt.scatter(df['sqft_lot'], df['price'])

# %%
plt.scatter(df['zipcode'], df['price'])

# %%
plt.rcParams["figure.figsize"] = (20,20)
plt.scatter(df['date'], df['price'])

# %%
plt.scatter(df['bedrooms'], df['price'])

# %%
#polynomial regression size of house and price
x= df[['sqft_lot','sqft_living','sqft_above','sqft_basement']]

# %%
y = df['price']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.3, random_state= 500)

# %%
len(x_train)
# Out:
# 15129

# %%
len(x_test)
# Out:
# 6484

# %%
from sklearn.linear_model import LinearRegression
clf = LinearRegression()
clf.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
clf.predict(x_test)
# Out:
# array([198891.65118845, 529069.06279623, 448602.53092106, ...,
#        491758.13144248, 885945.43626404, 992333.89512273])

# %%
clf.score(x_test, y_test)
# Out:
# 0.5056441178213924

# %%
df.isnull().values.any()
# Out:
# False

# %%
df.describe()
# Out:
#         Unnamed: 0         price      bedrooms     bathrooms   sqft_living  \
# count  21613.00000  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   10806.00000  5.400881e+05      3.370842      2.114757   2079.899736
# std     6239.28002  3.671272e+05      0.930062      0.770163    918.440897
# min        0.00000  7.500000e+04      0.000000      0.000000    290.000000
# 25%     5403.00000  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    10806.00000  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    16209.00000  6.450000e+05      4.000000      2.500000   2550.000000
# max    21612.00000  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
import seaborn as sns

# %%
bar = sns.barplot(df['grade'],df['price'], ci = None)
bar.set(title = 'Grade of property and prices')
bar.set(xlabel='Grade of home', ylabel = 'Price')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# [Text(0, 0.5, 'Price'), Text(0.5, 0, 'Grade of home')]

# %%
df['grade'].max()
# Out:
# 13

# %%
scat = sns.scatterplot(df['condition'],df['price'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# Regression Plot 
sns.regplot(df['grade'],df['price'], ci = None)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#residual model
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
from statsmodels.formula.api import ols

linear_model = ols('grade~price', data = df).fit()
print(linear_model.summary())
fig = plt.figure(figsize=(14, 8))
fig = sm.graphics.plot_regress_exog(linear_model,'price', fig=fig)
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
#                             OLS Regression Results
# ...
# Dep. Variable:                  grade   R-squared:                       0.445
# Model:                            OLS   Adj. R-squared:                  0.445
# Method:                 Least Squares   F-statistic:                 1.736e+04
# Date:                Tue, 26 Apr 2022   Prob (F-statistic):               0.00
# Time:                        11:50:07   Log-Likelihood:                -27789.
# No. Observations:               21613   AIC:                         5.558e+04
# Df Residuals:                   21611   BIC:                         5.560e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...

# %%
heatmap = sns.heatmap(df.corr(), annot = True)

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures

x = np.array(df['grade']).reshape(-1,1)
y = np.array(df['price'])


pre_process = PolynomialFeatures(degree=2, include_bias=False)

x_poly = pre_process.fit_transform(x)

pr_model = LinearRegression().fit(x_poly, y)

y_pred = pr_model.predict(x_poly)

# %%
r_sq = pr_model.score(x_poly, y)
print(r_sq)
print(pr_model.intercept_)
print(pr_model.coef_)
# Out:
# 0.5100481895752529
# 1633983.0029516434
# [-471327.49212202   41910.13782882]

# %%
#plot polynomial regression
#plt.scatter(x,y, c = 'black')
#plt.xlabel('Grade')
#plt.ylabel('Price')
#plt.plot(x, y_pred)

# %%
import numpy as np
import sklearn.model_selection 
price = np.array(df['price']).reshape(-1,1)
grade = np.array(df['grade'])
x_train,x_test,y_train,y_test=sklearn.model_selection.train_test_split(grade,price,test_size = 0.3)
print(x_train)
print(y_train)
print(x_test)
print(y_test)
# Out:
# [10  8  7 ...  6  7  9]
# [[590000.]
#  [729953.]
#  [468000.]
#  ...
#  [470000.]
#  [209950.]
#  [815000.]]
# [8 7 9 ... 7 7 8]
# [[1015000.]
#  [ 495000.]
#  [ 723000.]
#  ...
#  [ 270000.]
#  [ 305000.]
#  [ 346500.]]

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import r2_score

# %%
x_train_a = np.array(x_train).reshape(-1,1)
y_train_a = np.array(y_train)

x_test_a = np.array(x_test).reshape(-1,1)
y_test_a = np.array(y_test)


lr = LinearRegression()
lr.fit(x_train_a, y_train_a)
y_pred = lr.predict(x_test_a)
print(r2_score(y_test_a, y_pred))
# Out:
# 0.46286395875219855

# %%
#Linear regression for trained data 
plt.plot(x_train, lr.predict(x_train_a), color="r")
plt.plot(x, y, "b.")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

# %%
# applying polynomial regression degree 2
poly = PolynomialFeatures(degree=2, include_bias=True)
x_train_trans = poly.fit_transform(x_train_a)
x_test_trans = poly.transform(x_test_a)
#include bias parameter
lr = LinearRegression()
lr.fit(x_train_trans, y_train_a)
y_pred = lr.predict(x_test_trans)
print(r2_score(y_test_a, y_pred))
# Out:
# 0.5225792434782046

# %%
print(lr.coef_)
print(lr.intercept_)
# Out:
# [[      0.         -493477.99303441   43408.75689354]]
# [1715786.65139574]

# %%
# Regression Plot for Grade and Price
X_new = np.linspace(1,13).reshape(50, 1)
X_new_poly = poly.transform(X_new)
y_new = lr.predict(X_new_poly)
plt.plot(X_new, y_new, "r-", linewidth=2, label="Predictions")
plt.plot(x_train, y_train, "b.",label='Training points')
plt.plot(x_test, y_test, "g.",label='Testing points')
plt.xlabel("grade")
plt.ylabel("price")
plt.legend()
plt.show()
